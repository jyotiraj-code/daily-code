# %%
#The following code is for the visualization of the qubit

# %run quantum.py

# %%
#Drawing the quantum states as dots

from matplotlib.pyplot import plot, figure, show

#Drawing a figure
figure(figsize = (6,6), dpi =80)

#Drawing the axes
draw_axes()

#Drawing the origin
plot(0,0,'ro') #A point red to denote the origin

#Drawing the quantum states
plot(1,0,'bo')
plot(0,1,'go')
plot(0,-1,'co')
plot(-1,0,'yo')

# %%
#Now drawing the quantum states with arrows

from matplotlib.pyplot import figure, arrow, show

#Drawing a figure
figure(figsize = (6,6), dpi = 800)

#Drawing the axes
draw_axes()

# draw the quantum states as vectors (in red, blue, green, and yellow colors)
arrow(0,0,0.92,0,head_width=0.04, head_length=0.08, color="r")
arrow(0,0,0,0.92,head_width=0.04, head_length=0.08, color="b")
arrow(0,0,-0.92,0,head_width=0.04, head_length=0.08, color="g")
arrow(0,0,0,-0.92,head_width=0.04, head_length=0.08, color="y")

show()

# %%
# randomly creating a 2-dimensional quantum state
from random import randrange
def random_qstate_by_value():
    first_entry = randrange(-100,101)
    second_entry = randrange(-100,101)
    length_square = first_entry**2+second_entry**2
    while length_square == 0:
        first_entry = randrange(-100,101)
        second_entry = randrange(-100,101)
        length_square = first_entry**2+second_entry**2
    first_entry = first_entry / length_square**0.5
    second_entry = second_entry / length_square**0.5
    return [first_entry,second_entry]

# %%
#Drawing the quantum states

from matplotlib.pyplot import plot, figure, show
from random import randrange

#Drawing the figure
figure(figsize = (6,6), dpi = 800)

#Defining the central origin
plot(0,0, 'ro')

#Randomly choosing the colors
colors = ['bo','go','yo','co','mo','ko']

#Creatimg the random quantum state
for i in range(500):
    quantum_state = random_qstate_by_value();
    x = quantum_state[0];
    y = quantum_state[1];
    print(x,y,colors[randrange(len(colors))])

plot(x,y,colors[randrange(len(colors))])


show()
# Out:
# -0.43580854827079 -0.9000393931679359 go
# 0.9937118653325242 0.11196753412197455 bo
# -0.12855402864139476 -0.9917025066621882 yo
# 0.7682212795973759 0.6401843996644799 mo
# 0.9230769230769231 -0.38461538461538464 ko
# 0.07227426057847045 0.9973847959828921 go
# -0.7727262545252342 0.6347394233600138 yo
# 0.11856081112470786 -0.9929467931694284 ko
# -0.38595180380513083 0.9225189456805567 co
# -0.5312890373771262 0.8471906271689309 yo
# -0.9486832980505138 -0.31622776601683794 ko
# 0.8832568637022025 0.4688894461628976 co
# -0.8900433648586652 0.4558758698056578 mo
# -0.4597071249825724 -0.8880705823526966 go
# -0.7288480720939872 0.6846754616640485 go
# -0.9805806756909202 0.19611613513818404 bo
# 0.9820771339102746 0.18847944994237595 ko
# 0.9340518348510853 0.35713746626659143 yo
# -0.20540151173226015 0.9786777911948866 go
# -0.41158672242649835 -0.911370599658675 ko
# 0.5263546146162954 0.8502651466878618 mo
# -0.3643993485805122 0.9312427797057534 co
# ...

# %%
#Now drawing with arrows

#Drawing the quantum states

from matplotlib.pyplot import plot, figure, show
from random import randrange

#Drawing the figure
figure(figsize = (6,6), dpi = 800)

#Defining the central origin
plot(0,0, 'ro')

#Randomly choosing the colors
colors = ['b','g','y','c','m','k']

#Creatimg the random quantum state
for i in range(500):
    quantum_state = random_qstate_by_value();
    x = quantum_state[0];
    y = quantum_state[1];

    #Shortening the length of the arrows
    x_new = 0.92*x
    y_new = 0.92*y


    arrow(0,0,x,y,head_width=0.04, head_length=0.08, color = colors[randrange(len(colors))])


show()
